# %% [markdown]
# #Asignacion 1
# ###Estudiante: Anderson Palma

# %%
RutaArchivo= /content/drive/MyDrive/Archivos_Estadistica_Computacional/Libro1_EC.xlsx

# %% [markdown]
# Matriz 4x4
# \begin{vmatrix}
# 1 & -2 & 2 & 2 \\
# 0 & 4 & -2 & 1 \\
# 1 & -2 & 4 & 0 \\
# 1 & -1 & 2 & 2 \\
# \end{vmatrix}

# %% [markdown]
# Imagen Universidad Nacional de Colombia-Plaza central
# ![unal ](https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Plaza_Che%2C_Bogot%C3%A1.jpg/800px-Plaza_Che%2C_Bogot%C3%A1.jpg)

# %% [markdown]
# * [Dirección de la imagen] ( https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Plaza_Che%2C_Bogot%C3%A1.jpg/800px-Plaza_Che%2C_Bogot%C3%A1.jpg )

# %%
from tabulate import tabulate

d=[ ["ene", 12],
   ["feb", 11],
   ["mar", 14],
   ["abr", 12],
   ["may", 16],
   ["jun", 15],
   ["jul", 13],
   ["ago", 20],
   ["sep", 16],
   ["oct", 18],
   ["nov", 17],
   ["dic", 15],]
print(tabulate(d,headers=["mes", "tmed(°C)"]))
# Out:
# mes      tmed(°C)
# -----  ----------
# ene            12
# feb            11
# mar            14
# abr            12
# may            16
# jun            15
# jul            13
# ago            20
# sep            16
# oct            18
# nov            17
# dic            15

# %% [markdown]
# #Ecuación media aritmética o promedio
# $$\chi=\frac{\sum Xn}{n}$$
